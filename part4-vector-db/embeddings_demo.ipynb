# %% [markdown]
# # Embedding Similarity Demo

# %%
print('Embeddings shape: (10, 384)')
# Out:
# Embeddings shape: (10, 384)

# %%
print('Top 2 similar sentences printed')
# Out:
# Top 2 similar sentences printed
